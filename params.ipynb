# %%
import torch
import os
from prettytable import PrettyTable
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

def count_parameters(model):
    table = PrettyTable(["Modules", "Parameters"])
    total_params = 0
    params_list = []
    for name, parameter in model.named_parameters():
        if not parameter.requires_grad: continue
        params = parameter.numel()
        params_list.append((name,params))
    sorted_params_list = sorted(params_list,key=lambda x:x[1],reverse=True)
    for name,params in sorted_params_list:
        table.add_row([name, params])
        total_params+=params
    print(table)
    print(f"Total Trainable Params: {total_params}")

# %%
from models.gpt import GPT, GPTConfig
model_name = 'mini-gpt'
# init from a model saved in a specific directory
ckpt_path = os.path.join('out', model_name+'.pt')
checkpoint = torch.load(ckpt_path, map_location=device)
gptconf = GPTConfig(**checkpoint['model_args'])
model = GPT(gptconf)

state_dict = checkpoint['model']
unwanted_prefix = '_orig_mod.' # remove weird prefix (according to nanoGPT)
for k,v in list(state_dict.items()):
    if k.startswith(unwanted_prefix):
        state_dict[k[len(unwanted_prefix):]] = state_dict.pop(k)
model.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
count_parameters(model)
# Out:
# +-----------------------------------+------------+
# |              Modules              | Parameters |
# +-----------------------------------+------------+
# |          tok_embd.weight          |  19316736  |
# |             ff.weight             |  19316736  |
# |      blocks.0.ff.lin1.weight      |   589824   |
# |      blocks.0.ff.lin2.weight      |   589824   |
# |      blocks.1.ff.lin1.weight      |   589824   |
# |      blocks.1.ff.lin2.weight      |   589824   |
# |      blocks.2.ff.lin1.weight      |   589824   |
# |      blocks.2.ff.lin2.weight      |   589824   |
# |      blocks.3.ff.lin1.weight      |   589824   |
# |      blocks.3.ff.lin2.weight      |   589824   |
# |      blocks.4.ff.lin1.weight      |   589824   |
# |      blocks.4.ff.lin2.weight      |   589824   |
# |      blocks.5.ff.lin1.weight      |   589824   |
# |      blocks.5.ff.lin2.weight      |   589824   |
# |      blocks.0.csa.proj.weight     |   147456   |
# |      blocks.1.csa.proj.weight     |   147456   |
# |      blocks.2.csa.proj.weight     |   147456   |
# |      blocks.3.csa.proj.weight     |   147456   |
# |      blocks.4.csa.proj.weight     |   147456   |
# |      blocks.5.csa.proj.weight     |   147456   |
# |          pos_embd.weight          |   98304    |
# | blocks.0.csa.heads.0.query.weight |   24576    |
# |  blocks.0.csa.heads.0.key.weight  |   24576    |
# | blocks.0.csa.heads.0.value.weight |   24576    |
# | blocks.0.csa.heads.1.query.weight |   24576    |
# |  blocks.0.csa.heads.1.key.weight  |   24576    |
# | blocks.0.csa.heads.1.value.weight |   24576    |
# | blocks.0.csa.heads.2.query.weight |   24576    |
# |  blocks.0.csa.heads.2.key.weight  |   24576    |
# | blocks.0.csa.heads.2.value.weight |   24576    |
# | blocks.0.csa.heads.3.query.weight |   24576    |
# |  blocks.0.csa.heads.3.key.weight  |   24576    |
# | blocks.0.csa.heads.3.value.weight |   24576    |
# | blocks.0.csa.heads.4.query.weight |   24576    |
# |  blocks.0.csa.heads.4.key.weight  |   24576    |
# | blocks.0.csa.heads.4.value.weight |   24576    |
# | blocks.0.csa.heads.5.query.weight |   24576    |
# |  blocks.0.csa.heads.5.key.weight  |   24576    |
# | blocks.0.csa.heads.5.value.weight |   24576    |
# | blocks.1.csa.heads.0.query.weight |   24576    |
# |  blocks.1.csa.heads.0.key.weight  |   24576    |
# | blocks.1.csa.heads.0.value.weight |   24576    |
# | blocks.1.csa.heads.1.query.weight |   24576    |
# |  blocks.1.csa.heads.1.key.weight  |   24576    |
# | blocks.1.csa.heads.1.value.weight |   24576    |
# | blocks.1.csa.heads.2.query.weight |   24576    |
# |  blocks.1.csa.heads.2.key.weight  |   24576    |
# | blocks.1.csa.heads.2.value.weight |   24576    |
# | blocks.1.csa.heads.3.query.weight |   24576    |
# |  blocks.1.csa.heads.3.key.weight  |   24576    |
# | blocks.1.csa.heads.3.value.weight |   24576    |
# | blocks.1.csa.heads.4.query.weight |   24576    |
# |  blocks.1.csa.heads.4.key.weight  |   24576    |
# | blocks.1.csa.heads.4.value.weight |   24576    |
# | blocks.1.csa.heads.5.query.weight |   24576    |
# |  blocks.1.csa.heads.5.key.weight  |   24576    |
# | blocks.1.csa.heads.5.value.weight |   24576    |
# | blocks.2.csa.heads.0.query.weight |   24576    |
# |  blocks.2.csa.heads.0.key.weight  |   24576    |
# | blocks.2.csa.heads.0.value.weight |   24576    |
# | blocks.2.csa.heads.1.query.weight |   24576    |
# |  blocks.2.csa.heads.1.key.weight  |   24576    |
# | blocks.2.csa.heads.1.value.weight |   24576    |
# | blocks.2.csa.heads.2.query.weight |   24576    |
# |  blocks.2.csa.heads.2.key.weight  |   24576    |
# | blocks.2.csa.heads.2.value.weight |   24576    |
# | blocks.2.csa.heads.3.query.weight |   24576    |
# |  blocks.2.csa.heads.3.key.weight  |   24576    |
# | blocks.2.csa.heads.3.value.weight |   24576    |
# | blocks.2.csa.heads.4.query.weight |   24576    |
# |  blocks.2.csa.heads.4.key.weight  |   24576    |
# | blocks.2.csa.heads.4.value.weight |   24576    |
# | blocks.2.csa.heads.5.query.weight |   24576    |
# |  blocks.2.csa.heads.5.key.weight  |   24576    |
# | blocks.2.csa.heads.5.value.weight |   24576    |
# | blocks.3.csa.heads.0.query.weight |   24576    |
# |  blocks.3.csa.heads.0.key.weight  |   24576    |
# | blocks.3.csa.heads.0.value.weight |   24576    |
# | blocks.3.csa.heads.1.query.weight |   24576    |
# |  blocks.3.csa.heads.1.key.weight  |   24576    |
# | blocks.3.csa.heads.1.value.weight |   24576    |
# | blocks.3.csa.heads.2.query.weight |   24576    |
# |  blocks.3.csa.heads.2.key.weight  |   24576    |
# | blocks.3.csa.heads.2.value.weight |   24576    |
# | blocks.3.csa.heads.3.query.weight |   24576    |
# |  blocks.3.csa.heads.3.key.weight  |   24576    |
# | blocks.3.csa.heads.3.value.weight |   24576    |
# | blocks.3.csa.heads.4.query.weight |   24576    |
# |  blocks.3.csa.heads.4.key.weight  |   24576    |
# | blocks.3.csa.heads.4.value.weight |   24576    |
# | blocks.3.csa.heads.5.query.weight |   24576    |
# |  blocks.3.csa.heads.5.key.weight  |   24576    |
# | blocks.3.csa.heads.5.value.weight |   24576    |
# | blocks.4.csa.heads.0.query.weight |   24576    |
# |  blocks.4.csa.heads.0.key.weight  |   24576    |
# | blocks.4.csa.heads.0.value.weight |   24576    |
# | blocks.4.csa.heads.1.query.weight |   24576    |
# |  blocks.4.csa.heads.1.key.weight  |   24576    |
# | blocks.4.csa.heads.1.value.weight |   24576    |
# | blocks.4.csa.heads.2.query.weight |   24576    |
# |  blocks.4.csa.heads.2.key.weight  |   24576    |
# | blocks.4.csa.heads.2.value.weight |   24576    |
# | blocks.4.csa.heads.3.query.weight |   24576    |
# |  blocks.4.csa.heads.3.key.weight  |   24576    |
# | blocks.4.csa.heads.3.value.weight |   24576    |
# | blocks.4.csa.heads.4.query.weight |   24576    |
# |  blocks.4.csa.heads.4.key.weight  |   24576    |
# | blocks.4.csa.heads.4.value.weight |   24576    |
# | blocks.4.csa.heads.5.query.weight |   24576    |
# |  blocks.4.csa.heads.5.key.weight  |   24576    |
# | blocks.4.csa.heads.5.value.weight |   24576    |
# | blocks.5.csa.heads.0.query.weight |   24576    |
# |  blocks.5.csa.heads.0.key.weight  |   24576    |
# | blocks.5.csa.heads.0.value.weight |   24576    |
# | blocks.5.csa.heads.1.query.weight |   24576    |
# |  blocks.5.csa.heads.1.key.weight  |   24576    |
# | blocks.5.csa.heads.1.value.weight |   24576    |
# | blocks.5.csa.heads.2.query.weight |   24576    |
# |  blocks.5.csa.heads.2.key.weight  |   24576    |
# | blocks.5.csa.heads.2.value.weight |   24576    |
# | blocks.5.csa.heads.3.query.weight |   24576    |
# |  blocks.5.csa.heads.3.key.weight  |   24576    |
# | blocks.5.csa.heads.3.value.weight |   24576    |
# | blocks.5.csa.heads.4.query.weight |   24576    |
# |  blocks.5.csa.heads.4.key.weight  |   24576    |
# | blocks.5.csa.heads.4.value.weight |   24576    |
# | blocks.5.csa.heads.5.query.weight |   24576    |
# |  blocks.5.csa.heads.5.key.weight  |   24576    |
# | blocks.5.csa.heads.5.value.weight |   24576    |
# |        blocks.0.ln1.weight        |    384     |
# |        blocks.0.ln2.weight        |    384     |
# |        blocks.1.ln1.weight        |    384     |
# |        blocks.1.ln2.weight        |    384     |
# |        blocks.2.ln1.weight        |    384     |
# |        blocks.2.ln2.weight        |    384     |
# |        blocks.3.ln1.weight        |    384     |
# |        blocks.3.ln2.weight        |    384     |
# |        blocks.4.ln1.weight        |    384     |
# |        blocks.4.ln2.weight        |    384     |
# |        blocks.5.ln1.weight        |    384     |
# |        blocks.5.ln2.weight        |    384     |
# |             ln.weight             |    384     |
# |  blocks.0.csa.heads.0.query.bias  |     64     |
# |   blocks.0.csa.heads.0.key.bias   |     64     |
# |  blocks.0.csa.heads.0.value.bias  |     64     |
# |  blocks.0.csa.heads.1.query.bias  |     64     |
# |   blocks.0.csa.heads.1.key.bias   |     64     |
# |  blocks.0.csa.heads.1.value.bias  |     64     |
# |  blocks.0.csa.heads.2.query.bias  |     64     |
# |   blocks.0.csa.heads.2.key.bias   |     64     |
# |  blocks.0.csa.heads.2.value.bias  |     64     |
# |  blocks.0.csa.heads.3.query.bias  |     64     |
# |   blocks.0.csa.heads.3.key.bias   |     64     |
# |  blocks.0.csa.heads.3.value.bias  |     64     |
# |  blocks.0.csa.heads.4.query.bias  |     64     |
# |   blocks.0.csa.heads.4.key.bias   |     64     |
# |  blocks.0.csa.heads.4.value.bias  |     64     |
# |  blocks.0.csa.heads.5.query.bias  |     64     |
# |   blocks.0.csa.heads.5.key.bias   |     64     |
# |  blocks.0.csa.heads.5.value.bias  |     64     |
# |  blocks.1.csa.heads.0.query.bias  |     64     |
# |   blocks.1.csa.heads.0.key.bias   |     64     |
# |  blocks.1.csa.heads.0.value.bias  |     64     |
# |  blocks.1.csa.heads.1.query.bias  |     64     |
# |   blocks.1.csa.heads.1.key.bias   |     64     |
# |  blocks.1.csa.heads.1.value.bias  |     64     |
# |  blocks.1.csa.heads.2.query.bias  |     64     |
# |   blocks.1.csa.heads.2.key.bias   |     64     |
# |  blocks.1.csa.heads.2.value.bias  |     64     |
# |  blocks.1.csa.heads.3.query.bias  |     64     |
# |   blocks.1.csa.heads.3.key.bias   |     64     |
# |  blocks.1.csa.heads.3.value.bias  |     64     |
# |  blocks.1.csa.heads.4.query.bias  |     64     |
# |   blocks.1.csa.heads.4.key.bias   |     64     |
# |  blocks.1.csa.heads.4.value.bias  |     64     |
# |  blocks.1.csa.heads.5.query.bias  |     64     |
# |   blocks.1.csa.heads.5.key.bias   |     64     |
# |  blocks.1.csa.heads.5.value.bias  |     64     |
# |  blocks.2.csa.heads.0.query.bias  |     64     |
# |   blocks.2.csa.heads.0.key.bias   |     64     |
# |  blocks.2.csa.heads.0.value.bias  |     64     |
# |  blocks.2.csa.heads.1.query.bias  |     64     |
# |   blocks.2.csa.heads.1.key.bias   |     64     |
# |  blocks.2.csa.heads.1.value.bias  |     64     |
# |  blocks.2.csa.heads.2.query.bias  |     64     |
# |   blocks.2.csa.heads.2.key.bias   |     64     |
# |  blocks.2.csa.heads.2.value.bias  |     64     |
# |  blocks.2.csa.heads.3.query.bias  |     64     |
# |   blocks.2.csa.heads.3.key.bias   |     64     |
# |  blocks.2.csa.heads.3.value.bias  |     64     |
# |  blocks.2.csa.heads.4.query.bias  |     64     |
# |   blocks.2.csa.heads.4.key.bias   |     64     |
# |  blocks.2.csa.heads.4.value.bias  |     64     |
# |  blocks.2.csa.heads.5.query.bias  |     64     |
# |   blocks.2.csa.heads.5.key.bias   |     64     |
# |  blocks.2.csa.heads.5.value.bias  |     64     |
# |  blocks.3.csa.heads.0.query.bias  |     64     |
# |   blocks.3.csa.heads.0.key.bias   |     64     |
# |  blocks.3.csa.heads.0.value.bias  |     64     |
# |  blocks.3.csa.heads.1.query.bias  |     64     |
# |   blocks.3.csa.heads.1.key.bias   |     64     |
# |  blocks.3.csa.heads.1.value.bias  |     64     |
# |  blocks.3.csa.heads.2.query.bias  |     64     |
# |   blocks.3.csa.heads.2.key.bias   |     64     |
# |  blocks.3.csa.heads.2.value.bias  |     64     |
# |  blocks.3.csa.heads.3.query.bias  |     64     |
# |   blocks.3.csa.heads.3.key.bias   |     64     |
# |  blocks.3.csa.heads.3.value.bias  |     64     |
# |  blocks.3.csa.heads.4.query.bias  |     64     |
# |   blocks.3.csa.heads.4.key.bias   |     64     |
# |  blocks.3.csa.heads.4.value.bias  |     64     |
# |  blocks.3.csa.heads.5.query.bias  |     64     |
# |   blocks.3.csa.heads.5.key.bias   |     64     |
# |  blocks.3.csa.heads.5.value.bias  |     64     |
# |  blocks.4.csa.heads.0.query.bias  |     64     |
# |   blocks.4.csa.heads.0.key.bias   |     64     |
# |  blocks.4.csa.heads.0.value.bias  |     64     |
# |  blocks.4.csa.heads.1.query.bias  |     64     |
# |   blocks.4.csa.heads.1.key.bias   |     64     |
# |  blocks.4.csa.heads.1.value.bias  |     64     |
# |  blocks.4.csa.heads.2.query.bias  |     64     |
# |   blocks.4.csa.heads.2.key.bias   |     64     |
# |  blocks.4.csa.heads.2.value.bias  |     64     |
# |  blocks.4.csa.heads.3.query.bias  |     64     |
# |   blocks.4.csa.heads.3.key.bias   |     64     |
# |  blocks.4.csa.heads.3.value.bias  |     64     |
# |  blocks.4.csa.heads.4.query.bias  |     64     |
# |   blocks.4.csa.heads.4.key.bias   |     64     |
# |  blocks.4.csa.heads.4.value.bias  |     64     |
# |  blocks.4.csa.heads.5.query.bias  |     64     |
# |   blocks.4.csa.heads.5.key.bias   |     64     |
# |  blocks.4.csa.heads.5.value.bias  |     64     |
# |  blocks.5.csa.heads.0.query.bias  |     64     |
# |   blocks.5.csa.heads.0.key.bias   |     64     |
# |  blocks.5.csa.heads.0.value.bias  |     64     |
# |  blocks.5.csa.heads.1.query.bias  |     64     |
# |   blocks.5.csa.heads.1.key.bias   |     64     |
# |  blocks.5.csa.heads.1.value.bias  |     64     |
# |  blocks.5.csa.heads.2.query.bias  |     64     |
# |   blocks.5.csa.heads.2.key.bias   |     64     |
# |  blocks.5.csa.heads.2.value.bias  |     64     |
# |  blocks.5.csa.heads.3.query.bias  |     64     |
# |   blocks.5.csa.heads.3.key.bias   |     64     |
# |  blocks.5.csa.heads.3.value.bias  |     64     |
# |  blocks.5.csa.heads.4.query.bias  |     64     |
# |   blocks.5.csa.heads.4.key.bias   |     64     |
# |  blocks.5.csa.heads.4.value.bias  |     64     |
# |  blocks.5.csa.heads.5.query.bias  |     64     |
# |   blocks.5.csa.heads.5.key.bias   |     64     |
# |  blocks.5.csa.heads.5.value.bias  |     64     |
# +-----------------------------------+------------+
# Total Trainable Params: 49360512
